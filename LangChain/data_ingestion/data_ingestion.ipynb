# %%
from langchain_community.document_loaders import TextLoader
speechtxt=TextLoader("/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/speech.txt")

# %%
speechtxt.load()
# Out:
# [Document(metadata={'source': '/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/speech.txt'}, page_content='Speech is the human act of communicating thoughts, feelings, or information through spoken language, utilizing vocal folds, breath, and articulation to produce sound. It is a fundamental method of verbal communication, often delivered as a formal address or public presentation to engage an audience through storytelling, data, or rhetorical questions. \nYouTube\nYouTube\n +4\nKey aspects of speech include:\nDefinition: Speech is the ability to talk, a specific manner of speaking, or a formal discourse. It involves using the larynx, tongue, lips, and teeth to produce sounds.\nTypes of Speeches: These include informative (educating on a topic), persuasive (convincing an audience), and motivational speeches, such as personal narratives about overcoming challenges.\nEffective Delivery: Starting a speech effectively can involve storytelling, using a striking fact, or asking a rhet
# ...

# %%
from langchain_community.document_loaders import JSONLoader
product=JSONLoader("/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/products.json",jq_schema=".[]",text_content=False)

# %%
product.load()
# Out:
# [Document(metadata={'source': '/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/products.json', 'seq_num': 1}, page_content='{"id": "0005a4ea-ce3f-4dd7-bee0-f4ccc70fea6a", "sku": "XIAO-359GB-001", "name": "Xiaomi Model Pro", "description": "Official Xiaomi product with manufacturer warranty", "category": "laptops", "brand": "Xiaomi", "price": 25058, "currency": "INR", "discount_percent": 0, "stock": 45, "is_active": true, "rating": 4.8, "tags": ["charger", "amoled", "tablet"], "image_urls": ["https://cdn.example.com/xiaomi/front.png", "https://cdn.example.com/xiaomi/back.png"], "dimensions_cm": {"length": 27.4, "width": 20.8, "height": 1.9}, "seller": {"seller_id": "73cbdd06-5668-4e52-b172-e765f8468398", "name": "Mi Store", "email": "support@mistore.in", "website": "https://www.mistore.in"}, "created_at": "2024-09-06T00:00:00Z"}'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
resume=PyPDFLoader("/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/data_ingestion/Rahul_resume_2026_final.pdf")

# %%
resume.load()
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-14T14:40:24+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-14T14:40:24+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/data_ingestion/Rahul_resume_2026_final.pdf', 'total_pages': 1, 'page': 0, 'page_label': ''}, page_content='Rahul Manchanda\n+91 7082968702|rahulmanchanda015@gmail.com|LinkedIn|GitHub\nProfessional Summary\nAI Engineer and Data Enthusiast with hands-on experience buildingmachine learning pipelines, LLM-\npowered applications, and scalable backend systems. Skilled inPython, FastAPI, MLflow, and Large\nLanguage Model integrations (Gemini, Groq). Experienced in developing AI-driven platforms for recruit-\nment, cybersecurity, and career guidance.\nEducation\nPanipat Institute
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

# Step 1: Load PDF
loader = PyPDFLoader("/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/data_ingestion/Rahul_resume_2026_final.pdf")
pages = loader.load()

# Step 2: Clean function
def clean_text(text):
    return " ".join(text.split())

# Step 3: Format function
def format_pdf(page):
    content = clean_text(page.page_content)

    return f"""
    This is a candidate resume.

    Resume Content:
    {content}

    Key Objective:
    Extract skills, experience, education, and projects from this resume.
    """.strip()

# Step 4: Apply formatting
formatted_docs = [format_pdf(page) for page in pages]

# Preview
for doc in formatted_docs[:2]:
    print(doc)
# Out:
# This is a candidate resume.
#
#     Resume Content:
# ...

# %%
import os

path = "/Users/rahulmanchanda/Desktop/Agentic AI /LangChain/data_ingestion/Rahul_resume_2026_final.pdf"

print(os.path.exists(path))
# Out:
# True
