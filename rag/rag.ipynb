# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("speech.txt")
loader.load()
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='hey thios is speech .txt \n')]
